# %% [markdown]
# # Webscraping no IMDB com filmes do Denzel Washington

# %% [markdown]
# ## Informações sobre o ator - Nomes dos Filmes, links e anos de produção...
# Inspiração tirada deste script: https://github.com/SCloves/filmes_de_natal_iMDb/blob/master/filmes_natal_iMBDb.ipynb

# %%
import requests 
from bs4 import BeautifulSoup 
import pandas as pd 
import re

# %%
# url com a listagem de filmes do Denzel...
url_fonte = 'http://www.imdb.com/name/nm0000243/?ref_=nv_sr_1'

# %%
# se conectando da página
con = requests.get(url_fonte)

# %%
con.status_code
# Out:
# 200

# %%
# criando objeto BeautifulSoup com 
# o conteúdo html da página
soup = BeautifulSoup(con.content, "html.parser")

# %%
#print(soup.prettify())

# %%
#Pegando tudo relacionado a filmes: atuando(actor), produzindo(Producer), dirigindo(Director), trilha sonora, agradecimentos(thanks), aparições como ele mesmo(self)
#nomeFilmeTudo = [tag.find('a') for tag in soup.findAll('div', class_='filmo-row')]

nomeFilmeTudo = [tag.find('a') for tag in soup.findAll('div', class_='filmo-row')]
#nomeFilmeTudo

# %%
#Tratando caracteres indesejados com re para pegar somente os anos...

anoFilmeTudo = [tag.find('span') for tag in soup.findAll('div', class_='filmo-row')]

anosFilmes = []
for num in anoFilmeTudo:
    id = anoFilmeTudo.index(num)
    c = re.findall('\d+', str(anoFilmeTudo[id]))
    c = re.sub("\['", '', str(c))
    c = re.sub("\']", '', str(c))
    c = re.sub("\'\,", ' -', str(c))
    c = re.sub("\ '", ' ', str(c))
    anosFilmes.append(c)
    
#anosFilmes

# %%
# Usando re para pegar tudo o que está entre "" para gerar o link do filme ===> Ex: "/title/tt0168786/?ref_=nm_flmg_prd_8"
# Depois juntando o endereço do imdb para gerar o link completo ===> Ex: http://www.imdb.com/title/tt0168786/?ref_=nm_flmg_prd_8

linkPart = "http://www.imdb.com"
linksFilmes = []
for num in nomeFilmeTudo:
    id = nomeFilmeTudo.index(num)
    a = re.findall(r'"(.*?)"', str(nomeFilmeTudo[id]))
    a = re.sub("\['", '', str(a))
    a = re.sub("\']", '', str(a))
    a = linkPart + str(a)
    linksFilmes.append(a) 
    #print(linkCompl)
    
#len(linksFilmes)
#print (linksFilmes)

# %%
#Tratando caracteres indesejados com re para pegar somente os títulos dos filmes...

titulosFilmes =[]
for num in nomeFilmeTudo:
    id = nomeFilmeTudo.index(num)
    b = re.findall(r'>(.*?)<', str(nomeFilmeTudo[id]))
    b = re.sub("\['", '', str(b))
    b = re.sub("\']", '', str(b))
    b = re.sub('\["', '', str(b))
    b = re.sub('\"]', '', str(b))
    #a = linkPart + str(a)
    titulosFilmes.append(b) 
    #print(linkCompl)

#print (titulosFilmes)

# %% [markdown]
# ## Pegando Informações sobre cada produção ...

# %%
#TESTES ANTES DAS FUNÇÕES
#Para testar Funções...
#con2 = requests.get('http://www.imdb.com/title/tt6000478/?ref_=nm_flmg_act_2') 
#soup2 = BeautifulSoup(con2.content, "html.parser")

#Título do Filme
#titFilme = [tag.find('h1', itemprop='name') for tag in soup2.findAll('div', class_='title_wrapper')]
#titFilme = re.findall(r'>(.*?)<', str(titFilme))
#print(titFilme[0])
#print("===============")

#Ano do Filme
#anoFilme = [tag.find('a') for tag in soup2.findAll('span', id_='titleYear')]
#anoFilme = [tag.find('a') for tag in soup2.findAll('h1', itemprop='name')]
#anoFilme = re.findall(r'>(.*?)<', str(anoFilme))
#print(anoFilme[0])
#print("++++++++++++")

#Genero
#genero = [tag.find('span', itemprop='genre') for tag in soup2.findAll('div', class_='subtext')]
#genero = re.findall(r'>(.*?)<', str(genero))
#print (genero[0])
#print("|||||||||||||")
# colocando os gêneros(se tiver + de 1) na mesma linha???

#Nota IMDB
#rating = [tag.find('span', itemprop='ratingValue') for tag in soup2.findAll('div', class_='ratingValue')]
#rating = re.findall(r'>(.*?)<', str(rating))
#print (rating[0])
#print("----------------")

#Reviews
#reviews = [tag.find('span', itemprop='ratingCount') for tag in soup2.findAll('div', class_='imdbRating')]
#reviews = re.findall(r'>(.*?)<', str(reviews))
#reviews = str.replace(',','',str(reviews))
#print (reviews[0])
#print("----------------")

#Duracao
#duracao = [tag.find('time', itemprop='duration') for tag in soup2.findAll('div', class_='subtext')]
#duracao = re.findall(r'\d+', str(duracao))
#print(duracao[0])
#print("----------------")

#Nota Metascore
#metascore = [tag.find('span') for tag in soup2.findAll('div', class_='metacriticScore score_mixed titleReviewBarSubItem')]
#metascore = re.findall(r'>(.*?)<', str(metascore))
#print(metascore[0])
#print("----------------")

#Reviews Metascore - Usuarios
#revMetascore = [tag.find('span') for tag in soup2.findAll('div', class_='titleReviewBarItem titleReviewbarItemBorder')]
#revMetascore = re.findall(r'>(.*?)<', str(revMetascore))
#revMetascore = re.findall(r'\d+', str(revMetascore))
#print(revMetascore[0])
#print(revMetascore[1])
#print("------++++++++-----")

#Diretor
#diretor = [tag.find('span', itemprop='name') for tag in soup2.findAll('span', itemprop='director')]
#diretor = re.findall(r'>(.*?)<', str(diretor))
#print(diretor[0])
#print("_______________")

#Roteirista
#roteirista = [tag.find('span', itemprop='name') for tag in soup2.findAll('span', itemprop='creator')]
#roteirista = re.findall(r'>(.*?)<', str(roteirista))
#print(roteirista[0])
#print("*****************")

# %%
#Ano do Filme
def pegaAno(soup):
    #ano = soup.select("a[href*=/year/]")
    anoFilme = [tag.find('a') for tag in soup2.findAll('h1', itemprop='name')]
    anoFilme = re.findall(r'>(.*?)<', str(anoFilme))
    if len(anoFilme):
        return int(anoFilme[0])
    else:
        return None

#ano = pegaAno(soup2)
#print(ano)

# %%
#Gênero
def pegaGenero(soup):
    genFilme = [tag.find('span', itemprop='genre') for tag in soup2.findAll('div', class_='subtext')]
    genFilme = re.findall(r'>(.*?)<', str(genFilme))
    if len(genFilme):
        return str(genFilme[0])
    else:
        return None
    
#genero = pegaGenero(soup2)
#print(genero)

# %%
#Nota IMDB
def pegaNotaIMDB(soup):
    ratFilme = [tag.find('span', itemprop='ratingValue') for tag in soup2.findAll('div', class_='ratingValue')]
    ratFilme = re.findall(r'>(.*?)<', str(ratFilme))
    if len(ratFilme):
        return str(ratFilme[0])
    else:
        return None
    
#rating = pegaNotaIMDB(soup2)
#print(rating)

# %%
#Reviews
#con2 = requests.get('http://www.imdb.com/title/tt6000478/?ref_=nm_flmg_act_2') 
#soup2 = BeautifulSoup(con2.content, "html.parser")
def pegaReviewIMDB(soup):
    revFilme = [tag.find('span', itemprop='ratingCount') for tag in soup2.findAll('div', class_='imdbRating')]
    revFilme = re.findall(r'>(.*?)<', str(revFilme))
    if len(revFilme):
        revFilme[0] = re.sub(',', '', str(revFilme[0]))
        return int(revFilme[0])
    else:
        return None
    
#review = pegaReviewIMDB(soup2)
#print(review)
# Out:
# 14103

# %%
#Duração
def pegaDuracao(soup):
    durFilme = [tag.find('time', itemprop='duration') for tag in soup2.findAll('div', class_='subtext')]
    durFilme = re.findall(r'\d+', str(durFilme))
    if len(durFilme):
        return int(durFilme[0])
    else:
        return None
    
#duracao = pegaDuracao(soup2)
#print(duracao)

# %%
#Nota Metascore

#Conexão com filmes indicando o link de cada um no loop...
#con3 = requests.get('http://www.imdb.com/title/tt0454848/?ref_=nm_flmg_act_15')
#con3 = requests.get('http://www.imdb.com/title/tt0119099/?ref_=nm_flmg_act_27')
#soup3 = BeautifulSoup(con3.content, "html.parser")
#con3.close()

def pegaNotaMetaScore(soup):
    notaFilme = [tag.find('span') for tag in soup.findAll('div', class_='metacriticScore score_mixed titleReviewBarSubItem')]
    notaFilme = re.findall(r'>(.*?)<', str(notaFilme))
    notaFilme2 = [tag.find('span') for tag in soup.findAll('div', class_='metacriticScore score_favorable titleReviewBarSubItem')]
    notaFilme2 = re.findall(r'>(.*?)<', str(notaFilme2))
    notaFilme3 = [tag.find('span') for tag in soup.findAll('div', class_='metacriticScore score_unfavorable titleReviewBarSubItem')]
    notaFilme3 = re.findall(r'>(.*?)<', str(notaFilme3))
    if len(notaFilme):
        return int(notaFilme[0])
    elif len(notaFilme2):
        return int(notaFilme2[0])
    elif len(notaFilme3):
        return int(notaFilme3[0])
    else:
        return None
        
#notaMeta = pegaNotaMetaScore(soup3)
#print(notaMeta)
# Out:
# None

# %%
#Sinopse
#Conexão com filmes indicando o link de cada um no loop...
#con3 = requests.get('http://www.imdb.com/title/tt0454848/?ref_=nm_flmg_act_15')  
#soup3 = BeautifulSoup(con3.content, "html.parser")
#con3.close()

def pegaSinopse(soup):
    #sinFilme = [tag.find('div', class_='summary_text') for tag in soup.findAll('div', class_='plot_summary')]
    #sinFilme = re.findall(r'>(.*?)<', str(sinFilme))
    sinFilme = soup.find('div', class_='summary_text')
    if len(sinFilme):
        return str(sinFilme.text)
    else:
        return None
        
#sinopse = pegaSinopse(soup3)
#print(sinopse)

# %%
#Reviews Metascore - Usuarios
def pegaRevMetaScoreUser(soup):
    revScore = [tag.find('span') for tag in soup2.findAll('div', class_='titleReviewBarItem titleReviewbarItemBorder')]
    revScore = re.findall(r'>(.*?)<', str(revScore))
    revScore = re.findall(r'\d+', str(revScore))
    if len(revScore):
        return int(revScore[0])
    else:
        return None
    
#notaMeta = pegaRevMetaScoreUser(soup2)
#print(notaMeta)

# %%
#Reviews Metascore - Criticos
def pegaRevMetaScoreCrit(soup):
    revCrit = [tag.find('span') for tag in soup2.findAll('div', class_='titleReviewBarItem titleReviewbarItemBorder')]
    revCrit = re.findall(r'>(.*?)<', str(revCrit))
    revCrit = re.findall(r'\d+', str(revCrit))
    if len(revCrit):
        return int(revCrit[1])
    else:
        return None
    
#crit = pegaRevMetaScoreCrit(soup2)
#print(crit)

# %%
#Diretor
def pegaDiretor(soup):
    diretorFilme = [tag.find('span', itemprop='name') for tag in soup2.findAll('span', itemprop='director')]
    diretorFilme = re.findall(r'>(.*?)<', str(diretorFilme))
    if len(diretorFilme):
        return str(diretorFilme[0])
    else:
        return None
    
#diretor = pegaDiretor(soup2)
#print(diretor)

# %%
#Roteirista
def pegaRoteirista(soup):
    roteiristaFilme = [tag.find('span', itemprop='name') for tag in soup2.findAll('span', itemprop='creator')]
    roteiristaFilme = re.findall(r'>(.*?)<', str(roteiristaFilme))
    if len(roteiristaFilme):
        return str(roteiristaFilme[0])
    else:
        return None
    
#roteirista = pegaRoteirista(soup2)
#print(roteirista)

# %%
#Locações
#con3 = requests.get('https://www.imdb.com/title/tt0455944/?ref_=nm_flmg_act_5')  
#soup3 = BeautifulSoup(con3.content, "html.parser")
#con3.close()
#def pegaLocacao(soup):
#    locacaoFilme = [tag.find('a', itemprop='url') for tag in soup3.findAll('h4', class_='inline')]
#    #locacaoFilme = re.findall(r'>(.*?)<', str(locacaoFilme))
#    if len(locacaoFilme):
#        return str(locacaoFilme[0])
#    else:
#        return None
    
#locacao = pegaLocacao(soup3)
#print(locacao)
# Out:
# None

# %%
#BUDGET

# %%
#Opening Weekend USA

# %%
#Gross USA

# %%
#Cumulative Gross Worldwide

# %%
#Funções para pegar informações do filme...
#con2 = requests.get('http://www.imdb.com/title/tt6000478/?ref_=nm_flmg_act_2') 
#soup2 = BeautifulSoup(con2.content, "html.parser")

qtdFilmAct = 56 #Qtd de filmes q o Denzel atuou... o parametro ref_=nm_flmg_act_x indica isso no link do filme
film = {}
listaFilmes = []

for i in range(qtdFilmAct):
    
    #Conexão com filmes indicando o link de cada um no loop...
    con2 = requests.get(linksFilmes[i])  #http://www.imdb.com/title/tt2671706/?ref_=nm_flmg_act_3
    soup2 = BeautifulSoup(con2.content, "html.parser")
    con2.close()
    
    film['Titulo'] = titulosFilmes[i]
    film['Link'] = linksFilmes[i]
    film['Ano'] = pegaAno(soup2)
    film['Genero'] = pegaGenero(soup2)
    film['Duracao'] = pegaDuracao(soup2)
    film['Diretor'] = pegaDiretor(soup2)
    film['Roteirista'] = pegaRoteirista(soup2)
    film['Nota IMDB'] = pegaNotaIMDB(soup2)
    film['Qtd Rev IMDB'] = pegaReviewIMDB(soup2)
    film['Nota Metascore'] = pegaNotaMetaScore(soup2)
    film['Qtd Rev Metascore'] = pegaRevMetaScoreUser(soup2)
    film['Sinopse'] = pegaSinopse(soup2)
    ##film['Qtd Rev Metascore Criticos'] = pegaRevMetaScoreCrit(soup2)  #========> Ajustar
    
    listaFilmes.append(film.copy()) #Adicionando dicionario em uma lista
    #print(titulosFilmes[i] + ', ' + linksFilmes[i])

# %%
dfFilme = pd.DataFrame(listaFilmes, columns=[
    'Titulo','Ano','Genero','Duracao','Diretor','Roteirista','Nota IMDB','Qtd Rev IMDB','Nota Metascore','Qtd Rev Metascore',
    'Sinopse','Link'
])

#dfFilme
# Out:
# 4       263544.0            57.0              470.0
# 5       173153.0            55.0              178.0
# 6       287892.0            76.0              512.0
# 7       181901.0            52.0              280.0
# 8       164624.0            69.0              335.0
# 9       254153.0            53.0              582.0
# 10      164497.0            55.0              293.0
# 11       51488.0            65.0              122.0
# 12      350500.0            76.0              470.0
# 13      264132.0            59.0              418.0
# 14      298100.0            76.0              664.0
# 15       93348.0            76.0              370.0
# 16      292091.0            47.0              704.0
# 17       50391.0            63.0              159.0
# 18       29072.0            62.0              159.0
# 19      109417.0            30.0              401.0
# 20      338025.0            69.0              651.0
# 21      176283.0            48.0              405.0
# 22       82867.0            74.0              271.0
# 23      133601.0            45.0              408.0
# 24       62311.0            53.0              291.0
# 25       39216.0            63.0              114.0
# 26       64810.0             NaN              244.0
# 27         423.0             NaN                1.0
# 28          94.0             NaN                1.0
# 29        9658.0             NaN               49.0
# 30       44344.0            77.0              111.0
# 31       14849.0            78.0               60.0
# 32       25241.0            39.0               89.0
# 33       88827.0            66.0              198.0
# 34       65848.0            50.0               96.0
# 35      196689.0            66.0              275.0
# 36       40315.0             NaN              179.0
# 37       71172.0            72.0              165.0
# 38         462.0             NaN                2.0
# 39       13894.0             NaN               60.0
# 40        4222.0             NaN               33.0
# 41        9259.0             NaN               31.0
# 42        2712.0             NaN               14.0
# 43      109393.0             NaN              423.0
# 44        3950.0            71.0               27.0
# 45        2802.0             NaN               36.0
# 46        1905.0             NaN               13.0
# 47       10967.0            59.0               51.0
# 48         510.0             NaN                5.0
# 49        2363.0             NaN               16.0
# 50        7469.0             NaN               48.0
# 51         745.0             NaN               10.0
# 52        2084.0             NaN               24.0
# 53          72.0             NaN                NaN
# 54         173.0             NaN                3.0
# 55         168.0             NaN                1.0
#
#                                               Sinopse  \
# 0   \n                    Robert McCall serves an ...
# 1   \n                    Roman J. Israel, Esq., a...
# 2   \n                    A working-class African-...
# 3   \n                    Seven gunmen in the old ...
# 4   \n                    A man believes he has pu...
# 5   \n                    Two hardened criminals g...
# 6   \n                    An airline pilot saves a...
# 7   \n                    A young CIA agent is tas...
# 8   \n                    With an unmanned, half-m...
# 9   \n                    A post-apocalyptic tale,...
# 10  \n                    Armed men hijack a New Y...
# 11  \n                    A drama based on the tru...
# 12  \n                    An outcast New York City...
# 13  \n                    After a ferry is bombed ...
# 14  \n                    A police detective, a ba...
# 15  \n                    In the midst of the Gulf...
# 16  \n                    In Mexico City, a former...
# 17  \n                    A Florida police chief m...
# 18  \n                    Antwone Fisher, a young ...
# 19  \n                    John Quincy Archibald ta...
# 20  \n                    On his first day on the ...
# 21  \n                    The true story of a newl...
# 22  \n                    The story of Rubin "Hurr...
# 23  \n                    A quadriplegic ex-homici...
# 24  \n                    The secret U.S. abductio...
# 25  \n                    A basketball player's fa...
# 26  \n                    Homicide detective John ...
# 27  \n                    Multicultural versions o...
# 28  \n                    Feeling under appreciate...
# 29  \n                    Good natured Reverend He...
# 30  \n                    A U.S. Army officer, des...
# 31  \n                    An African-American man ...
# 32  \n                    When a virtual reality s...
# 33  \n                    On a U.S. nuclear missil...
# 34  \n                    A law student uncovers a...
# 36  http://www.imdb.com/title/tt0107616/?ref_=nm_f...
# 37  http://www.imdb.com/title/tt0104797/?ref_=nm_f...
# 38  http://www.imdb.com/title/tt0159876/?ref_=nm_f...
# 39  http://www.imdb.com/title/tt0102789/?ref_=nm_f...
# 40  http://www.imdb.com/title/tt0102456/?ref_=nm_f...
# 41  http://www.imdb.com/title/tt0100168/?ref_=nm_f...
# 42  http://www.imdb.com/title/tt0099750/?ref_=nm_f...
# 43  http://www.imdb.com/title/tt0097441/?ref_=nm_f...
# 44  http://www.imdb.com/title/tt0097880/?ref_=nm_f...
# 45  http://www.imdb.com/title/tt0083483/?ref_=nm_f...
# 46  http://www.imdb.com/title/tt0097373/?ref_=nm_f...
# 47  http://www.imdb.com/title/tt0092804/?ref_=nm_f...
# 48  http://www.imdb.com/title/tt0091106/?ref_=nm_f...
# 49  http://www.imdb.com/title/tt0091786/?ref_=nm_f...
# 50  http://www.imdb.com/title/tt0088146/?ref_=nm_f...
# 51  http://www.imdb.com/title/tt0087617/?ref_=nm_f...
# 52  http://www.imdb.com/title/tt0082138/?ref_=nm_f...
# 53  http://www.imdb.com/title/tt0078999/?ref_=nm_f...
# 54  http://www.imdb.com/title/tt0079161/?ref_=nm_f...
# 55  http://www.imdb.com/title/tt0076923/?ref_=nm_f...

# %%
dfFilme.dtypes
# Out:
# Titulo                object
# Ano                  float64
# Genero                object
# Duracao              float64
# Diretor               object
# Roteirista            object
# Nota IMDB             object
# Qtd Rev IMDB         float64
# Nota Metascore       float64
# Qtd Rev Metascore    float64
# Sinopse               object
# Link                  object
# dtype: object

# %%
#Preenchendo valores NaN com zero
dfFilme['Ano'].fillna(value=0, inplace=True)
dfFilme['Duracao'].fillna(value=0, inplace=True)
dfFilme['Qtd Rev IMDB'].fillna(value=0, inplace=True)
dfFilme['Nota Metascore'].fillna(value=0, inplace=True)
dfFilme['Qtd Rev Metascore'].fillna(value=0, inplace=True)

# %%
#Tratando valores do dataframe
dfFilme['Ano'] = dfFilme['Ano'].astype(int)
dfFilme['Duracao'] = dfFilme['Duracao'].astype(int)
dfFilme['Qtd Rev IMDB'] = dfFilme['Qtd Rev IMDB'].astype(int)
dfFilme['Qtd Rev IMDB'] = dfFilme['Qtd Rev IMDB'].astype(int)
dfFilme['Nota Metascore'] = dfFilme['Nota Metascore'].astype(int)
dfFilme['Qtd Rev Metascore'] = dfFilme['Qtd Rev Metascore'].astype(int)

dfFilme.dtypes
# Out:
# Titulo               object
# Ano                   int32
# Genero               object
# Duracao               int32
# Diretor              object
# Roteirista           object
# Nota IMDB            object
# Qtd Rev IMDB          int32
# Nota Metascore        int32
# Qtd Rev Metascore     int32
# Sinopse              object
# Link                 object
# dtype: object

# %%
dfFilme
# Out:
#                                              Titulo   Ano     Genero  Duracao  \
# 0                                      O Protetor 2  2018     Action        0
# 1                             Roman J. Israel, Esq.  2017      Crime      122
# 2                               Um Limite Entre Nós  2016      Drama      139
# 3                          Sete Homens e um Destino  2016     Action      132
# 4                                        O Protetor  2014     Action      132
# 5                                        Dose Dupla  2013     Action      109
# 6                                             O Voo  2012      Drama      138
# 42          2712               0                 14
# 43        109393               0                423
# 44          3950              71                 27
# 45          2802               0                 36
# 46          1905               0                 13
# 47         10967              59                 51
# 48           510               0                  5
# 49          2363               0                 16
# 50          7469               0                 48
# 51           745               0                 10
# 52          2084               0                 24
# 53            72               0                  0
# 54           173               0                  3
# 55           168               0                  1
#
#                                               Sinopse  \
# 0   \n                    Robert McCall serves an ...
# 1   \n                    Roman J. Israel, Esq., a...
# 2   \n                    A working-class African-...
# 3   \n                    Seven gunmen in the old ...
# 4   \n                    A man believes he has pu...
# 5   \n                    Two hardened criminals g...
# 6   \n                    An airline pilot saves a...
# 7   \n                    A young CIA agent is tas...
# 8   \n                    With an unmanned, half-m...
# 9   \n                    A post-apocalyptic tale,...
# 10  \n                    Armed men hijack a New Y...
# 11  \n                    A drama based on the tru...
# 12  \n                    An outcast New York City...
# 13  \n                    After a ferry is bombed ...
# 14  \n                    A police detective, a ba...
# 15  \n                    In the midst of the Gulf...
# 16  \n                    In Mexico City, a former...
# 17  \n                    A Florida police chief m...
# 18  \n                    Antwone Fisher, a young ...
# 19  \n                    John Quincy Archibald ta...
# 20  \n                    On his first day on the ...
# 21  \n                    The true story of a newl...
# 22  \n                    The story of Rubin "Hurr...
# 23  \n                    A quadriplegic ex-homici...
# 24  \n                    The secret U.S. abductio...
# 25  \n                    A basketball player's fa...
# 26  \n                    Homicide detective John ...
# 27  \n                    Multicultural versions o...
# 28  \n                    Feeling under appreciate...
# 29  \n                    Good natured Reverend He...
# 30  \n                    A U.S. Army officer, des...
# 31  \n                    An African-American man ...
# 32  \n                    When a virtual reality s...
# 33  \n                    On a U.S. nuclear missil...
# 34  \n                    A law student uncovers a...
# 35  \n                    When a man with HIV is f...
# 36  \n                    Young lovers Hero and Cl...
# 37  \n                    Biographical epic of the...
# 38  \n                    "You Can't Take It With ...
# 39  \n                    A District Attorney is t...
# 40  \n                    An Indian family is expe...
# 41  \n                    Jazz trumpeter Bleek Gil...
# 42  \n                    A racist cop receives a ...
# 43  \n                    Robert Gould Shaw leads ...
# 44  \n                    When police officer Xavi...
# 45  \n                    The lives and work of th...
# 46  \n                    A retired British soldie...
# 47  \n                    South African journalist...
# 48  \n                    He risked it all to make...
# 49  \n                    After a close friend dro...
# 50  \n                    An African American offi...
# 51  \n                    A grieving family whose ...
# 52  \n                    When a rich white corpor...
# 53  \n                    A banished hero of Rome ...
# 54  \n                    A convict takes up boxin...
# 55  \n                    The story of American tr...
#
#                                                  Link
# 0   http://www.imdb.com/title/tt3766354/?ref_=nm_f...
# 1   http://www.imdb.com/title/tt6000478/?ref_=nm_f...
# 2   http://www.imdb.com/title/tt2671706/?ref_=nm_f...
# 3   http://www.imdb.com/title/tt2404435/?ref_=nm_f...
# 4   http://www.imdb.com/title/tt0455944/?ref_=nm_f...
# 5   http://www.imdb.com/title/tt1272878/?ref_=nm_f...
# 6   http://www.imdb.com/title/tt1907668/?ref_=nm_f...
# 7   http://www.imdb.com/title/tt1599348/?ref_=nm_f...
# 8   http://www.imdb.com/title/tt0477080/?ref_=nm_f...
# 9   http://www.imdb.com/title/tt1037705/?ref_=nm_f...
